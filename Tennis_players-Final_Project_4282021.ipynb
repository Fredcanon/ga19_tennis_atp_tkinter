# %%
####Goal: Build a tennis player comparison app

####why?
# fun sport, fun project !

####highlights
#3 different data sources
#uses pandas, tkinter and random
# creates a custom window with drop down menus,
# buttons and custom table

####pain points
# cleaning and scraping the data 
# summing up wins by player over 21 years of ATP matches
# instead of vlookup use df.merge()!
####new tools
# installing dash :/ -> so I found tkinter
# tkinter is a new interface! buttons, drop down menus

####next steps
# add photos for each player via wiki API
# so much match data

# %%
import pandas as pd

#making sure that the column names display fully
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

df_players = pd.read_csv('tennis_atp-master/atp_players.csv')

#add a header to the ranking file
df_ranking = pd.read_csv('tennis_atp-master/atp_rankings_current.csv', header = None)

#OS module to grab names of files in tennis_atp-master
import os
files = os.listdir('tennis_atp-master')
files.sort()

matches = []
for f in files:
    if 'atp_matches' in f:
        matches.append(pd.read_csv(f'tennis_atp-master/{f}'))

df_temp = pd.concat(matches)

# clean matches (reduce the number of columns)
cmatches = df_temp[['tourney_id','tourney_date','tourney_name','match_num','winner_id','surface','winner_name','winner_hand','winner_ht','loser_id','loser_name','loser_hand','loser_ht','score', 'best_of', 'round','minutes', 'w_ace','l_ace']]
cmatches.to_csv('tennis_atp-master/matches_clean.csv')

# %%
#leaving this in as a reminder of iteration
#only run 1 time to add a header
#df_players.to_csv('tennis_atp-master/atp_players.csv', header =['player_id','first_name','last_name','hand','birth_date','country'], index = False)
#df_players = pd.read_csv('tennis_atp-master/atp_players.csv')

#run the code below only one time to add a header
#df_ranking.to_csv('tennis_atp-master/atp_rankings_current.csv', header =['date','rank','player_id','points'], index = False)
#df_ranking = pd.read_csv('tennis_atp-master/atp_rankings_current.csv')

#files = files.remove('.DS_Store')
#print(matches)

#type(cmatches)
#cmatches.head()

# %%
#sum up wins and loses by player over all 21 years
#save all wins by player
win_grp = cmatches.groupby('winner_id', sort=True).size()
win_grp
#df_players['wins']= win_grp
df_players.head(100)
win_grp.to_csv('tennis_atp-master/win_grp.csv')

#save all loses by player
lose_grp = cmatches.groupby('loser_id', sort = True).size()
lose_grp.to_csv('tennis_atp-master/lose_grp.csv')

win_grp = pd.DataFrame(win_grp)
win_grp.columns = ["wins"]
win_grp

lose_grp = pd.DataFrame(lose_grp)
lose_grp.columns = ["loses"]

df_tennis = pd.merge(win_grp, lose_grp, left_index = True, right_index = True)
df_tennis
# Out:
#         wins  loses
# 100644   257    130
# 100754     2      4
# 101086     7     19
# 101150    34     46
# 101185     3      7
# ...      ...    ...
# 208055     1      2
# 208518     1      1
# 209080     1      1
# 209226     2      1
# 210013    16     26
#
# [1447 rows x 2 columns]

# %%
#number of finals attended and titles won by 
finals = cmatches[(cmatches['round'] == 'F')]
    
finals_grp = finals.groupby(['winner_id','loser_id']).size().reset_index(name='finals_attended')
finals_grp
titles_grp = finals.groupby('winner_id').size()
type(titles_grp)

titles_grp = pd.DataFrame(titles_grp)
titles_grp.columns = ["titles"]

# %%
#count player id in wins and loses
df_finals_grp = finals_grp[['winner_id', 'loser_id']].apply(pd.Series.value_counts, result_type = 'expand')

# results in NaNs
df_finals_grp = df_finals_grp.fillna(0)
df_finals_grp

#create the attended column
attended = df_finals_grp['winner_id'] + df_finals_grp['loser_id']

df_finals_grp['attended'] = attended
#df_finals_grp.columns =('player_id','winner_id', 'loser_id','attended')
df_finals_grp.to_csv('tennis_atp-master/finals_attended.csv')
df_finals_grp

df_finals_grp = pd.DataFrame(df_finals_grp.attended)
df_finals_grp.columns = ["finals attended"]

#merging finals and titles columns
df_tennis = pd.merge(df_tennis, df_finals_grp, left_index = True, right_index = True)
df_tennis = pd.merge(df_tennis, titles_grp, left_index = True, right_index = True)
# Out:
#         wins  loses  finals attended  titles
# 100644   257    130             20.0      14
# 101320    36     32              1.0       1
# 101532    65     83              3.0       1
# 101611    59     58              2.0       2
# 101723    32     26              2.0       1
# 101736   272     86             22.0      16
# 101820    61     78              2.0       2
# 101885   115    144              2.0       1
# 101948   104     47              8.0       3
# 101962   171    128             10.0       4
# 101964    54     64              1.0       1
# 101965   124    100              1.0       2
# 102021    67     75              2.0       1
# 102035   186    197              4.0       2
# 102106   122    173              5.0       2
# 102148   227    217              5.0       4
# 102158    82     37              7.0       2
# 102179    76    117              2.0       1
# 102184    32     51              2.0       1
# 102202    95    107              2.0       2
# 102231    56     79              2.0       1
# 102247    40     70              2.0       2
# 102257   165    127              7.0       6
# 102259    76     67              3.0       1
# 102287    89    131              2.0       1
# 102318   205    191              6.0       2
# 102338   204    118             14.0       7
# 102344    97     96              3.0       2
# 102358   146    124              6.0       3
# 102369    60     77              2.0       1
# 102374   155    106              9.0       8
# 102434   171    211              3.0       1
# 102450   295    154             12.0       7
# 102456   127    116              5.0       2
# 102524    12     21              1.0       1
# 102562   232    163             10.0       5
# 102563   229    186             10.0       6
# 102607    38     46              2.0       1
# 102610   153    133              4.0       1
# 102644   103    103              3.0       2
# 102694    66    118              2.0       1
# 102701   107     75              6.0       3
# 102703   145    157              2.0       1
# 102765   122     84              5.0       3
# 102776    41     66              2.0       1
# 102783   289    292             11.0       3
# 102788    30     60              1.0       1
# 102796   116     85              9.0       5
# 102839   201    202              6.0       2
# 102845   380    205             24.0      15
# 102854   182    140              7.0       5
# 102856   222    110             21.0      15
# 102860   207    186              8.0       3
# 102882   136    105             10.0       4
# 102905   175    217              4.0       2
# 102950   102    149              3.0       2
# 102998   143    143              5.0       2
# 103017   242    196             12.0       2
# 103018   223    218              4.0       1
# 103084   231    150             16.0       8
# 103096   272    269              9.0       4
# 103103   261    232             11.0       5
# 103110    33     53              1.0       1
# 103151   150    159              4.0       2
# 103163   455    275             22.0      15
# 103176    87    115              2.0       2
# 103193    32     38              2.0       1
# 103206   289    196              9.0       4
# 103252   180    225              3.0       1
# 103264    88     79              8.0       2
# 103280    59     69              4.0       2
# 103285   384    300             12.0       6
# 103292   264    181             17.0       8
# 103325    58     70              1.0       1
# 103333   372    343             20.0       9
# 103344   415    276             22.0      11
# 103387   232    186              9.0       5
# 103420    34     49              1.0       1
# 103428   328    274             14.0       7
# 103454   253    232             16.0       7
# 103484   367    253             20.0      10
# 103490    38     59              1.0       1
# 103498   368    218             24.0      14
# 103507   463    254             29.0      15
# 103566   187    223             10.0       5
# 103592     8     18              1.0       1
# 103598   274    257             10.0       3
# 103602   370    202             20.0      13
# 103607    80     79              3.0       3
# 103632   135    143              3.0       2
# 103656   257    287             10.0       6
# 103672    60     94              1.0       1
# 103694   238    277             10.0       2
# 103714    78     95              3.0       1
# 103720   565    234             33.0      29
# 103722   123    170              3.0       2
# 103758   151    136              7.0       4
# 103781   352    335             13.0       5
# 103786   484    338             22.0      21
# 103794   154    221              3.0       1
# 103812   201    244              5.0       1
# 103813   411    349             11.0       2
# 103819  1236    256             72.0     103
# 103835   178    225              8.0       2
# 103852   501    462             17.0       7
# 103857    89    151              1.0       1
# 103888   303    223             16.0       6
# 103893   110    184              4.0       1
# 103900   383    196             22.0      11
# 103908   276    308              9.0       4
# 103909   219    116             18.0      10
# 103917   181    226              6.0       4
# 103970   740    379             33.0      27
# 103990   532    359             22.0      12
# 104022   499    422             20.0      10
# 104026    72     61              3.0       3
# 104053   612    215             37.0      32
# 104068   189    204              4.0       3
# 104076   193    183             10.0       4
# 104098   234    223              8.0       7
# 104122   136    194              3.0       2
# 104180   232    213              8.0       2
# 104198   299    354              9.0       5
# 104214   238    231             10.0       4
# 104252   244    264              8.0       3
# 104259   474    388             20.0       8
# 104269   552    425             22.0       7
# 104312   379    406             10.0       3
# 104327   119    137              3.0       2
# 104330    57     94              3.0       2
# 104332    89    107              3.0       1
# 104338   343    274             22.0      10
# 104339   208    135             11.0       3
# 104386   289    261             13.0       6
# 104417   310    172             20.0      11
# 104468   498    375             20.0      14
# 104471   118    140              2.0       1
# 104527   536    313             24.0      16
# 104542   471    229             25.0      18
# 104545   436    273             24.0      15
# 104547    91    133              3.0       2
# 104571   350    274             14.0       4
# 104586   124    158              4.0       2
# 104597   400    279             19.0      13
# 104607   643    344             27.0      14
# 104655   232    208             10.0       6
# 104660   172    213              4.0       4
# 104665   147    214              9.0       4
# 104678   297    272             10.0       5
# 104719   203    250              6.0       4
# 104731   344    237             19.0       6
# 104745  1018    211             50.0      86
# 104755   552    340             28.0      15
# 104792   494    285             27.0      10
# 104797   230    261              5.0       2
# 104871   292    293              3.0       1
# 104898   229    270              5.0       2
# 104918   686    207             34.0      46
# 104919   180    198              5.0       2
# 104925   956    193             39.0      83
# 104926   375    324             18.0       9
# 104976    35     57              1.0       1
# 104979    67    117              3.0       1
# 104999   134    200              3.0       1
# 105023   375    307             19.0      10
# 105062   168    216              4.0       1
# 105064   203    218              8.0       4
# 105077   228    251              9.0       2
# 105138   325    192             18.0      10
# 105173   208    245             10.0       1
# 105208   245    237              7.0       6
# 105216    55     86              1.0       1
# 105223   443    177             27.0      22
# 105227   523    292             28.0      18
# 105238   220    203              8.0       3
# 105311   196    228             10.0       3
# 105332   225    248              9.0       3
# 105357    90    111              3.0       1
# 105373   147    156              6.0       6
# 105376    62     76              3.0       1
# 105430    85    110              1.0       1
# 105449   171    172              6.0       4
# 105453   413    206             21.0      12
# 105550   113    125              5.0       1
# 105554    83     88              3.0       1
# 105583   140    175              3.0       1
# 105643   137    160              4.0       2
# 105676   292    190             12.0       5
# 105683   377    183             18.0       8
# 105777   335    217             13.0       8
# 105806    32     36              1.0       1
# 105807   204    170              8.0       5
# 105815    41     60              2.0       1
# 105916    97     89              3.0       1
# 105932   105    120              6.0       4
# 105992   120    159              3.0       1
# 106000   118    130              4.0       3
# 106043   178    149             11.0       4
# 106058   166    132              8.0       4
# 106065    52     92              4.0       3
# 106071   186    185              6.0       4
# 106121    50     83              1.0       1
# 106148    56     68              1.0       1
# 106210   127    145              3.0       2
# 106228    31     40              2.0       1
# 106233   304    162             24.0      17
# 106234    17     14              1.0       1
# 106298   135    112              9.0       5
# 106378   118    116              3.0       2
# 106401   166     96              9.0       6
# 106415    67     78              2.0       1
# 106421   174     86             16.0      11
# 106426    66     56              6.0       5
# 106432   166    143              7.0       2
# 111513    62     65              3.0       2
# 111575   147    117              4.0       4
# 111797    53     58              3.0       1
# 124187    49     52              2.0       2
# 126094   155     92             12.0       9
# 126203   108    107              5.0       1
# 126207    76     98              2.0       1
# 126610    79     55              5.0       3
# 126774   157     81             13.0       7
# 128034    63     59              3.0       3
# 132283    48     52              3.0       2
# 133430   111     89              2.0       1
# 134770    68     55              3.0       1
# 200005    47     43              2.0       2
# 200175    46     42              2.0       1
# 200282    90     64              9.0       4
# 200615    27     33              1.0       1
# 205734     7      9              1.0       1
# 206173    42     26              3.0       2
# 207678     6      2              1.0       1

# %%
df_players['name'] = df_players['first_name'] + " " + df_players['last_name']
df_players.index = df_players.player_id
df_players = df_players [['name','country','hand']]

df_tennis = pd.merge(df_tennis, df_players, left_index = True, right_index = True)


df_tennis = df_tennis[['name','country','hand','wins','loses','finals attended','titles']]
df_tennis
# Out:
#                                name country hand  wins  loses  finals attended  titles
# 100644             Alexander Zverev     GER    R   257    130             20.0      14
# 101320            Magnus Gustafsson     SWE    R    36     32              1.0       1
# 101532             Francisco Clavet     ESP    L    65     83              3.0       1
# 101611               Cedric Pioline     FRA    R    59     58              2.0       2
# 101723               Magnus Larsson     SWE    R    32     26              2.0       1
# 101736                 Andre Agassi     USA    R   272     86             22.0      16
# 101820                  Marc Rosset     SUI    R    61     78              2.0       2
# 101885                Wayne Arthurs     AUS    L   115    144              2.0       1
# 101948                 Pete Sampras     USA    R   104     47              8.0       3
# 101962            Younes El Aynaoui     MAR    R   171    128             10.0       4
# 101964             Goran Ivanisevic     CRO    L    54     64              1.0       1
# 101965               Wayne Ferreira     RSA    R   124    100              1.0       2
# 102021                Michael Chang     USA    R    67     75              2.0       1
# 102035               Jonas Bjorkman     SWE    R   186    197              4.0       2
# 102106           Davide Sanguinetti     ITA    R   122    173              5.0       2
# 102148              Fabrice Santoro     FRA    R   227    217              5.0       4
# 102158               Patrick Rafter     AUS    R    82     37              7.0       2
# 102179                Antony Dupuis     FRA    R    76    117              2.0       1
# 102184               David Prinosil     GER    R    32     51              2.0       1
# 102202              Kenneth Carlsen     DEN    L    95    107              2.0       2
# 102231               Alex Calatrava     ESP    R    56     79              2.0       1
# 102247              Andrea Gaudenzi     ITA    R    40     70              2.0       2
# 102257                Greg Rusedski     GBR    L   165    127              7.0       6
# 102259               Jerome Golmard     FRA    L    76     67              3.0       1
# 102287                Albert Portas     ESP    R    89    131              2.0       1
# 102318                 Andrei Pavel     ROU    R   205    191              6.0       2
# 102338           Yevgeny Kafelnikov     RUS    R   204    118             14.0       7
# 102344                 Karol Kucera     SVK    R    97     96              3.0       2
# 102358               Thomas Enqvist     SWE    R   146    124              6.0       3
# 102369               Julien Boutter     FRA    R    60     77              2.0       1
# 102374                Alex Corretja     ESP    R   155    106              9.0       8
# 102434               Vincent Spadea     USA    R   171    211              3.0       1
# 102450                   Tim Henman     GBR    R   295    154             12.0       7
# 102456               Felix Mantilla     ESP    R   127    116              5.0       2
# 102524               Neville Godwin     RSA    R    12     21              1.0       1
# 102562                   Jiri Novak     CZE    R   232    163             10.0       5
# 102563             Thomas Johansson     SWE    R   229    186             10.0       6
# 102607                Juan Balcells     ESP    R    38     46              2.0       1
# 102610                 Albert Costa     ESP    R   153    133              4.0       1
# 102644             Franco Squillari     ARG    L   103    103              3.0       2
# 102694             Lars Burgsmuller     GER    R    66    118              2.0       1
# 102701                 Marcelo Rios     CHI    L   107     75              6.0       3
# 102703               Hyung Taik Lee     KOR    R   145    157              2.0       1
# 102765               Nicolas Escude     FRA    R   122     84              5.0       3
# 102776                  Andrew Ilie     AUS    R    41     66              2.0       1
# 102783            Rainer Schuettler     GER    R   289    292             11.0       3
# 102788                    Jan Vacek     CZE    R    30     60              1.0       1
# 102796                Magnus Norman     SWE    R   116     85              9.0       5
# 102839             Nicolas Lapentti     ECU    R   201    202              6.0       2
# 102845                  Carlos Moya     ESP    R   380    205             24.0      15
# 102854               Sjeng Schalken     NED    R   182    140              7.0       5
# 102856              Gustavo Kuerten     BRA    R   222    110             21.0      15
# 102860              Agustin Calleri     ARG    R   207    186              8.0       3
# 102882           Mark Philippoussis     AUS    R   136    105             10.0       4
# 102905                Stefan Koubek     AUT    L   175    217              4.0       2
# 102950             Fernando Vicente     ESP    R   102    149              3.0       2
# 102998          Jan Michael Gambill     USA    R   143    143              5.0       2
# 103017               Nicolas Kiefer     GER    R   242    196             12.0       2
# 103018                   Max Mirnyi     BLR    R   223    218              4.0       1
# 103084              Guillermo Canas     ARG    R   231    150             16.0       8
# 103096               Arnaud Clement     FRA    R   272    269              9.0       4
# 103103               Dominik Hrbaty     SVK    R   261    232             11.0       5
# 103110            Daniele Bracciali     ITA    R    33     53              1.0       1
# 103151             Mariano Zabaleta     ARG    R   150    159              4.0       2
# 103163                   Tommy Haas     GER    R   455    275             22.0      15
# 103176                David Sanchez     ESP    R    87    115              2.0       2
# 103193                Peter Wessels     NED    R    32     38              2.0       1
# 103206           Sebastien Grosjean     FRA    R   289    196              9.0       4
# 103252               Alberto Martin     ESP    R   180    225              3.0       1
# 103264               Mariano Puerta     ARG    L    88     79              8.0       2
# 103280               Martin Verkerk     NED    R    59     69              4.0       2
# 103285               Radek Stepanek     CZE    R   384    300             12.0       6
# 103292                Gaston Gaudio     ARG    R   264    181             17.0       8
# 103325                Wesley Moodie     RSA    R    58     70              1.0       1
# 103333                 Ivo Karlovic     CRO    R   372    343             20.0       9
# 103344                Ivan Ljubicic     CRO    R   415    276             22.0      11
# 103387          Paradorn Srichaphan     THA    R   232    186              9.0       5
# 103420                Michal Tabara     CZE    R    34     49              1.0       1
# 103428           Juan Ignacio Chela     ARG    R   328    274             14.0       7
# 103454                Nicolas Massu     CHI    R   253    232             16.0       7
# 103484                  James Blake     USA    R   367    253             20.0      10
# 103490             Santiago Ventura     ESP    R    38     59              1.0       1
# 103498                  Marat Safin     RUS    R   368    218             24.0      14
# 103507          Juan Carlos Ferrero     ESP    R   463    254             29.0      15
# 103566               Michael Llodra     FRA    L   187    223             10.0       5
# 103592               Jerome Haehnel     FRA    R     8     18              1.0       1
# 103598               Xavier Malisse     BEL    R   274    257             10.0       3
# 103602            Fernando Gonzalez     CHI    R   370    202             20.0      13
# 103607              Victor Estrella     DOM    R    80     79              3.0       3
# 103632                   Luis Horna     PER    R   135    143              3.0       2
# 103656              Albert Montanes     ESP    R   257    287             10.0       6
# 103672                Ricardo Mello     BRA    L    60     94              1.0       1
# 103694               Olivier Rochus     BEL    R   238    277             10.0       2
# 103714          Andreas Vinciguerra     SWE    L    78     95              3.0       1
# 103720               Lleyton Hewitt     AUS    R   565    234             33.0      29
# 103722                Florent Serra     FRA    R   123    170              3.0       2
# 103758                  Taylor Dent     USA    R   151    136              7.0       4
# 103781                Jurgen Melzer     AUT    L   352    335             13.0       5
# 103786            Nikolay Davydenko     RUS    R   484    338             22.0      21
# 103794              Benjamin Becker     GER    R   154    221              3.0       1
# 103812               Victor Hanescu     ROU    R   201    244              5.0       1
# 103813              Jarkko Nieminen     FIN    L   411    349             11.0       2
# 103819                Roger Federer     SUI    R  1236    256             72.0     103
# 103835             Filippo Volandri     ITA    R   178    225              8.0       2
# 103852              Feliciano Lopez     ESP    L   501    462             17.0       7
# 103857                Igor Kunitsyn     RUS    R    89    151              1.0       1
# 103888                   Mardy Fish     USA    R   303    223             16.0       6
# 103893                Paolo Lorenzi     ITA    R   110    184              4.0       1
# 103900             David Nalbandian     ARG    R   383    196             22.0      11
# 103908           Paul Henri Mathieu     FRA    R   276    308              9.0       4
# 103909              Guillermo Coria     ARG    R   219    116             18.0      10
# 103917                Nicolas Mahut     FRA    R   181    226              6.0       4
# 103970                 David Ferrer     ESP    R   740    379             33.0      27
# 103990                Tommy Robredo     ESP    R   532    359             22.0      12
# 104022              Mikhail Youzhny     RUS    R   499    422             20.0      10
# 104026            Joachim Johansson     SWE    R    72     61              3.0       3
# 104053                 Andy Roddick     USA    R   612    215             37.0      32
# 104068                Robby Ginepri     USA    R   189    204              4.0       3
# 104076                 Jose Acasuso     ARG    R   193    183             10.0       4
# 104098              Dmitry Tursunov     RUS    R   234    223              8.0       7
# 104122               Carlos Berlocq     ARG    R   136    194              3.0       2
# 104180                Gilles Muller     LUX    L   232    213              8.0       2
# 104198       Guillermo Garcia Lopez     ESP    R   299    354              9.0       5
# 104214                 Igor Andreev     RUS    R   238    231             10.0       4
# 104252                Florian Mayer     GER    R   244    264              8.0       3
# 104259        Philipp Kohlschreiber     GER    R   474    388             20.0       8
# 104269            Fernando Verdasco     ESP    L   552    425             22.0       7
# 104312                Andreas Seppi     ITA    R   379    406             10.0       3
# 104327                 Steve Darcis     BEL    R   119    137              3.0       2
# 104330                   Rajeev Ram     USA    R    57     94              3.0       2
# 104332           Philipp Petzschner     GER    R    89    107              3.0       1
# 104338                  Juan Monaco     ARG    R   343    274             22.0      10
# 104339                  Mario Ancic     CRO    R   208    135             11.0       3
# 104386             Janko Tipsarevic     SRB    R   289    261             13.0       6
# 104417              Robin Soderling     SWE    R   310    172             20.0      11
# 104468                 Gilles Simon     FRA    R   498    375             20.0      14
# 104471                   Ivan Dodig     CRO    R   118    140              2.0       1
# 104527           Stanislas Wawrinka     SUI    R   536    313             24.0      16
# 104542           Jo Wilfried Tsonga     FRA    R   471    229             25.0      18
# 104545                   John Isner     USA    R   436    273             24.0      15
# 104547             Horacio Zeballos     ARG    L    91    133              3.0       2
# 104571             Marcos Baghdatis     CYP    R   350    274             14.0       4
# 104586                  Lukas Rosol     CZE    R   124    158              4.0       2
# 104597              Nicolas Almagro     ESP    R   400    279             19.0      13
# 104607                Tomas Berdych     CZE    R   643    344             27.0      14
# 104655                 Pablo Cuevas     URU    R   232    208             10.0       6
# 104660            Sergiy Stakhovsky     UKR    R   172    213              4.0       4
# 104665                Pablo Andujar     ESP    R   147    214              9.0       4
# 104678               Viktor Troicki     SRB    R   297    272             10.0       5
# 104719            Marcel Granollers     ESP    R   203    250              6.0       4
# 104731               Kevin Anderson     RSA    R   344    237             19.0       6
# 104745                 Rafael Nadal     ESP    L  1018    211             50.0      86
# 104755              Richard Gasquet     FRA    R   552    340             28.0      15
# 104792                 Gael Monfils     FRA    R   494    285             27.0      10
# 104797                Denis Istomin     UZB    R   230    261              5.0       2
# 104871                Jeremy Chardy     FRA    R   292    293              3.0       1
# 104898                  Robin Haase     NED    R   229    270              5.0       2
# 104918                  Andy Murray     GBR    R   686    207             34.0      46
# 104919               Leonardo Mayer     ARG    R   180    198              5.0       2
# 104925               Novak Djokovic     SRB    R   956    193             39.0      83
# 104926                Fabio Fognini     ITA    R   375    324             18.0       9
# 104976                Ryan Sweeting     USA    R    35     57              1.0       1
# 104979               Andrey Golubev     KAZ    R    67    117              3.0       1
# 104999                Mischa Zverev     GER    L   134    200              3.0       1
# 105023                  Sam Querrey     USA    R   375    307             19.0      10
# 105062            Mikhail Kukushkin     KAZ    R   168    216              4.0       1
# 105064              Thomaz Bellucci     BRA    L   203    218              8.0       4
# 105077                 Albert Ramos     ESP    L   228    251              9.0       2
# 105138        Roberto Bautista Agut     ESP    R   325    192             18.0      10
# 105173             Adrian Mannarino     FRA    L   208    245             10.0       1
# 105208               Ernests Gulbis     LAT    R   245    237              7.0       6
# 105216                Yuichi Sugita     JPN    R    55     86              1.0       1
# 105223        Juan Martin Del Potro     ARG    R   443    177             27.0      22
# 105227                  Marin Cilic     CRO    R   523    292             28.0      18
# 105238          Alexandr Dolgopolov     UKR    R   220    203              8.0       3
# 105311                   Joao Sousa     POR    R   196    228             10.0       3
# 105332                 Benoit Paire     FRA    R   225    248              9.0       3
# 105357                 John Millman     AUS    R    90    111              3.0       1
# 105373                Martin Klizan     SVK    L   147    156              6.0       6
# 105376              Peter Gojowczyk     GER    R    62     76              3.0       1
# 105430                   Radu Albot     MDA    R    85    110              1.0       1
# 105449                Steve Johnson     USA    R   171    172              6.0       4
# 105453                Kei Nishikori     JPN    R   413    206             21.0      12
# 105550                  Guido Pella     ARG    L   113    125              5.0       1
# 105554                 Daniel Evans     GBR    R    83     88              3.0       1
# 105583                Dusan Lajovic     SRB    R   140    175              3.0       1
# 105643            Federico Delbonis     ARG    L   137    160              4.0       2
# 105676                 David Goffin     BEL    R   292    190             12.0       5
# 105683                 Milos Raonic     CAN    R   377    183             18.0       8
# 105777              Grigor Dimitrov     BUL    R   335    217             13.0       8
# 105806                  Mirza Basic     BIH    R    32     36              1.0       1
# 105807          Pablo Carreno Busta     ESP    R   204    170              8.0       5
# 105815              Tennys Sandgren     USA    R    41     60              2.0       1
# 105916             Marton Fucsovics     HUN    R    97     89              3.0       1
# 105932         Nikoloz Basilashvili     GEO    R   105    120              6.0       4
# 105992                Ryan Harrison     USA    R   120    159              3.0       1
# 106000                Damir Dzumhur     BIH    R   118    130              4.0       3
# 106043  Diego Sebastian Schwartzman     ARG    R   178    149             11.0       4
# 106058                    Jack Sock     USA    R   166    132              8.0       4
# 106065             Marco Cecchinato     ITA    R    52     92              4.0       3
# 106071                Bernard Tomic     AUS    R   186    185              6.0       4
# 106121                  Taro Daniel     JPN    R    50     83              1.0       1
# 106148      Roberto Carballes Baena     ESP    R    56     68              1.0       1
# 106210                  Jiri Vesely     CZE    L   127    145              3.0       2
# 106228         Juan Ignacio Londero     ARG    R    31     40              2.0       1
# 106233                Dominic Thiem     AUT    R   304    162             24.0      17
# 106234               Aslan Karatsev     RUS    R    17     14              1.0       1
# 106298                Lucas Pouille     FRA    R   135    112              9.0       5
# 106378                  Kyle Edmund     GBR    R   118    116              3.0       2
# 106401                 Nick Kyrgios     AUS    R   166     96              9.0       6
# 106415           Yoshihito Nishioka     JPN    L    67     78              2.0       1
# 106421              Daniil Medvedev     RUS    R   174     86             16.0      11
# 106426              Christian Garin     CHI    R    66     56              6.0       5
# 106432                  Borna Coric     CRO    R   166    143              7.0       2
# 111513                  Laslo Djere     SRB    R    62     65              3.0       2
# 111575              Karen Khachanov     RUS    R   147    117              4.0       4
# 111797                Nicolas Jarry     CHI    R    53     58              3.0       1
# 124187                Reilly Opelka     USA    R    49     52              2.0       2
# 126094                Andrey Rublev     RUS    R   155     92             12.0       9
# 126203           Taylor Harry Fritz     USA    R   108    107              5.0       1
# 126207               Francis Tiafoe     USA    R    76     98              2.0       1
# 126610            Matteo Berrettini     ITA    R    79     55              5.0       3
# 126774           Stefanos Tsitsipas     GRE    R   157     81             13.0       7
# 128034               Hubert Hurkacz     POL    R    63     59              3.0       3
# 132283               Lorenzo Sonego     ITA    R    48     52              3.0       2
# 133430             Denis Shapovalov     CAN    L   111     89              2.0       1
# 134770                  Casper Ruud     NOR    R    68     55              3.0       1
# 200005                  Ugo Humbert     FRA    L    47     43              2.0       2
# 200175            Miomir Kecmanovic     SRB    R    46     42              2.0       1
# 200282               Alex De Minaur     AUS    R    90     64              9.0       4
# 200615               Alexei Popyrin     AUS    R    27     33              1.0       1
# 205734          Thiago Seyboth Wild     BRA    R     7      9              1.0       1
# 206173                Jannik Sinner     ITA    R    42     26              3.0       2
# 207678        Juan Manuel Cerundolo     ARG    L     6      2              1.0       1

# %%
df_tennis.to_csv('Tennis_ranking2.csv')

# %%
# done 
## open

# build df that goes through matches and count wins by player
#GOAL: compare skills and attributes by player
## use flask with heroku as interface

# first_name, last_name, birth_date, country_code
# ranking, ranking_points
# hand, height (cm), wins, losses
# number of titles won
# number of finals attended
## how many aces 
## average game length (when won?)
## wins per surface (clay, grass, hard) -> win-hard, lose-hard, win-grass
## add photos from the wiki API
## add performance Graphs

#Based on a work at https://github.com/JeffSackmann.
